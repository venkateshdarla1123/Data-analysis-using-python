# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[11,22,33,44,55,66,77,88,99]
plt.plot(x,y)
plt.title("My first class")
plt.xlabel("X values")
plt.ylabel("Y values")
#line graph
#title,lables,legend,colour,width,markers
# Out:
# Text(0, 0.5, 'Y values')

# %%
s1=[67,45,73,71,57]
s2=[43,67,68,53,85]
cut=[70,70,70,70,70]
sub=["psy","nano","med","onco","anthro"]
plt.plot(sub,s1,label="student 1")
plt.plot(sub,s2,label="student 2")
plt.plot(sub,cut,label="cutoff")
plt.legend()

# %%
#an ind vs aus match is on live ind has given 298 as target for australia the runs for every 5ov is given as follows
ind=[25,51,84,131,160,189,220,250,267,297]
#aus have completed 25 overs
aus=[15,41,94,110,151]
#plot overs vs runs for both the countries with india as blue line and aus as yellow line give appropriate labels and legend the marker for india is flag and aus is Plus
#take overs from arange function create runs as arrays

# %%
import numpy as np

# %%
ind=np.array([25,51,84,131,160,189,220,250,267,297])
aus=np.array([15,41,94,110,151])
overs=np.arange(1,51,5)
plt.title("IND VS AUS")
plt.plot(overs,ind,label="India",marker=">")
over2=np.arange(1,25,5)
plt.plot(over2,aus,label="Australia",marker="P",color="yellow")
plt.xlabel("OVERS")
plt.ylabel("RUNS")
plt.legend()
plt.grid()
