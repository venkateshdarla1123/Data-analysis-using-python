# %%
import requests
api_key = "9f5ea1f4733d440582e53549242802"
city = input("Enter your favourite city:\n")
url = f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
response = requests.get(url)
data = response.json()
print(data)
if response.status_code==200:
    print("city:",data['location']['name'])
else:
    print(data['error']['message'])
# Out:
# Enter your favourite city:
# guntur
# {'location': {'name': 'Guntur', 'region': 'Andhra Pradesh', 'country': 'India', 'lat': 16.3, 'lon': 80.45, 'tz_id': 'Asia/Kolkata', 'localtime_epoch': 1709390159, 'localtime': '2024-03-02 20:05'}, 'current': {'last_updated_epoch': 1709389800, 'last_updated': '2024-03-02 20:00', 'temp_c': 28.0, 'temp_f': 82.4, 'is_day': 0, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png', 'code': 1003}, 'wind_mph': 5.6, 'wind_kph': 9.0, 'wind_degree': 130, 'wind_dir': 'SE', 'pressure_mb': 1011.0, 'pressure_in': 29.85, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 66, 'cloud': 25, 'feelslike_c': 31.0, 'feelslike_f': 87.8, 'vis_km': 6.0, 'vis_miles': 3.0, 'uv': 1.0, 'gust_mph': 17.6, 'gust_kph': 28.4}}
# city: Guntur

# %%
print("State:",data['location']['region'])
# Out:
# State: Andhra Pradesh

# %%
print("country:",data['location']['country'])
# Out:
# country: India

# %%
print("temperature:",data['current']['temp_c'])
# Out:
# temperature: 28.0

# %%
 print("humidity:",data['current']['humidity'])
# Out:
# humidity: 66

# %%
print("wind speed:",data['current']['wind_mph'])
# Out:
# wind speed: 5.6

# %%
print("wind direction:",data['current']['wind_dir'])
# Out:
# wind direction: SE

# %%
print("Feels:",data['current']['feelslike_c'])
# Out:
# Feels: 31.0

# %%
type(data)
# Out:
# dict

# %%
print("city:",data['location']['name'])
print("State:",data['location']['region'])
print("country:",data['location']['country'])
print("humidity:",data['current']['humidity'])
print("temperature:",data['current']['temp_c'])
print("wind speed:",data['current']['wind_mph'])
print("wind direction:",data['current']['wind_dir'])
print("Feels:",data['current']['feelslike_c'])
# Out:
# city: Guntur
# State: Andhra Pradesh
# country: India
# humidity: 66
# temperature: 28.0
# wind speed: 5.6
# wind direction: SE
# Feels: 31.0
